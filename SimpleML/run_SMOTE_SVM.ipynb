# %%
# Basic models
import traceback
import numpy as np
import pandas as pd

# Data operation models
from sklearn.model_selection import StratifiedKFold
from sklearn import cross_validation
from sklearn.model_selection import ParameterGrid

# Classifier models
from sklearn.svm import SVC

# Evaluation models
import sklearn.metrics as sm
# Out:
# //anaconda/envs/tensorflow/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Configurations for the model
def run_Config():
    data_name = 'Cardiac_Death_dummy.xlsx'
    k_holdout = 10
    k_cv = 5
    origin_pars = {
            'indicator_name': ['macc'],
            'k_smote': [1,3,5], # smote_hyper-par
            'r_newpoint': [1,2,3], # smote_hyper-par
            'kernel': ['rbf'],
            'C': [0.1,1,10,100],
            'gamma': [2,3],
            'class_weight':[{1:0.4,2:0.6},{1:0.5,2:0.5}]
            }
    pars = list(ParameterGrid(origin_pars))
    return data_name, k_holdout, k_cv, pars

# %%
# Load data
def run_load_data(data_name):
    all = pd.read_excel(data_name)
    all = all.values
    all_fea = all[:,:-1]
    all_label = get_normal_label(all[:,-1])
    return all_fea, all_label

def get_normal_label(y):
    y_uni = np.unique(np.array(y))
    for i in xrange(len(y_uni)):
        y[np.nonzero(y == y_uni[i])[0]] = i+1
    return y

# %%
# Run both HoldoutCV and GridSearchCV
def run_doubleCV(all_fea, all_label, k_holdout, k_cv, pars):
    # HoldoutCV
    i_t = 0
    res_list = []
    opt_pars_list = []
    holdoutcv = StratifiedKFold(n_splits = k_holdout, shuffle = True)
    for i_learn, i_test in holdoutcv.split(all_fea, all_label):
        # Times
        i_t = i_t + 1
        print 'Round ', str(i_t), ' Holdout CV----------------------'
        
        # Obtain current learning and heldout data
        learn_fea, test_fea = all_fea[i_learn], all_fea[i_test]
        learn_label, test_label = all_label[i_learn], all_label[i_test]
        
        # GridSearchCV
        j_t = 0
        optdata = {'score':0}
        for i_pars in pars:
            # times
            j_t = j_t + 1
            print 'round ', str(j_t), ' gridsearch cv----------------'
            pars_score = []
            gridcv = StratifiedKFold(n_splits = k_cv, shuffle = True)
            for i_train, i_valid in gridcv.split(learn_fea, learn_label):
                # obtain current training and validation data
                train_fea, valid_fea = learn_fea[i_train], learn_fea[i_valid]
                train_label, valid_label = learn_label[i_train], learn_label[i_valid]
                # learn the model
                # i_pars = {'par_name1':par1,'par_name2':par2,...,'par_nameN':parN}
                valid_pre, pars_new = run_smote_model(i_pars, train_fea, train_label, valid_fea, 0)
                grid_score = run_validation(valid_pre, valid_label, i_pars['indicator_name'])
                pars_score.append(grid_score)
            if np.mean(pars_score) > optdata['score']:
                optdata['pars'] = pars_new
                optdata['score'] = np.mean(pars_score)
                    
        # Holdout testing
        # best_pars is a dict too
        best_pars = optdata['pars']
        test_pre, _ = run_smote_model(best_pars, learn_fea, learn_label, test_fea, 1)
        
        # Evaluate the prediction
        res_now = run_evaluation(test_pre, test_label)
        
        # Save results
        res_list.append(res_now)
        opt_pars_list.append(best_pars)
        
    return res_list, opt_pars_list

# %%
# Fit the model and make the prediction
def run_smote_model(p, X, y, Z, i_tag):
    if i_tag == 0:
        # run the smote to get new training data
        X_new, y_new, k_new, r_new = run_SMOTE(X, y, p['k_smote'], p['r_newpoint'])
        # update k_smote and r_newpoint
        p['k_smote'] = k_new
        p['r_newpoint'] = r_new
    else:
        X_new, y_new = X, y
    
    # run basic model
    clf = SVC(C=p['C'], kernel=p['kernel'], gamma=p['gamma'], class_weight=p['class_weight'])
    clf.fit(X_new,y_new)
    zpre = clf.predict(Z)
    print 'SMOTE-SVM is running...'
    return zpre, p

# %%
"""# Oversampling by SMOTE
def run_SMOTE(X, y, k, r):
    return X, y, k, r"""
# Out:
# '# Oversampling by SMOTE\ndef run_SMOTE(X, y, k, r):\n    return X, y, k, r'

# %%
# Oversampling by SMOTE
from sklearn.neighbors import NearestNeighbors as kNN
def run_SMOTE(X, y, k, r):
    
    # obtain postive and negative data
    v = np.unique(y)
    if len(v) == 2:
        if sum(y == v[0]) >= sum(y == v[1]):
            X_pos = X[y == v[1],:]
            X_neg = X[y == v[0],:]
            y_pos = y[y == v[1]]
            y_neg = y[y == v[0]]
        else:
            X_pos = X[y == v[0],:]
            X_neg = X[y == v[1],:]
            y_pos = y[y == v[0]]
            y_neg = y[y == v[1]]
    else:
        raise Exception("Not a binary-class!")    
    n_pos = X_pos.shape[0]
    n_neg = X_neg.shape[0]
    
    # constrain hyper-parameters to their suitable ranges
    if n_pos == 0:
        raise Exception("No positive samples!")
    elif k + 1 > n_pos:
        k = n_pos - 1
    else:
        while k > 1:
            while r > 1:
                if n_pos + n_pos*k*r >= n_neg:
                    r = r - 1
                else:
                    break   
            if n_pos + n_pos*k*r >= n_neg:
                k = k - 1
            else:
                break
    
    # find k nearest neighbors of each positive sample
    kNN_model = kNN(n_neighbors=k+1)
    kNN_model.fit(X_pos)
    i_neighbor = np.argsort(kNN_model.kneighbors(X_pos, return_distance = False), axis = 1)
    i_neighbor = i_neighbor[:,1:]
    
    # generate new positive samples and corresponding labels
    new_pos_mat = []
    for i in xrange(n_pos):
        now_sample = X_pos[i,:]
        for j in xrange(k):
                new_sample_mat = get_new_pos(now_sample, X_pos[i_neighbor[i,j],:], r)
                new_pos_mat.extend(new_sample_mat)
    new_pos_label = y_pos[0] * np.ones((len(new_pos_mat)))
    
    # combine the newly-generated ones to the original data
    X_new = np.concatenate((X_neg, X_pos, new_pos_mat), axis = 0)
    y_new = np.concatenate((y_neg, y_pos, new_pos_label), axis = 0)                                 
    i_shuffle = np.random.permutation(len(y_new))
    X_new = X_new[i_shuffle, :] 
    y_new = y_new[i_shuffle] 
    
    return X_new, y_new, k, r

def get_new_pos(point, neighbor, r):
    # Function to generate new r samples according to point and one of its neighbor
    new_points = []
    for i_r in xrange(r):
        new_point = point + (point - neighbor) * np.random.rand(point.shape[0])
        new_points.extend(np.array([new_point]))
    return new_points

# %%
# Obtain the score
def run_validation(zpre, z, s_name):
    i_pos = np.nonzero(z == max(z))
    i_neg = np.nonzero(z == min(z))
    tpr = (1 - sm.hamming_loss(z[i_pos], zpre[i_pos]))*100
    tnr = (1 - sm.hamming_loss(z[i_neg], zpre[i_neg]))*100
    if s_name.lower() == 'macc':
        s = 0.5*(tpr+tnr)
    elif s_name.lower() == 'gm':
        s = np.sqrt(tpr*tnr)
    elif s_name.lower() == 'tpr':
        s = tpr
    else: # error
        s = sum((1 if i_pre == i_true else 0 for i_pre, i_true in zip(zpre,z)))/float(len(z))
    return s

# %%
# Evaluate the performance
def run_evaluation(p, y):
    res_dict = {}
    i_pos = np.nonzero(y == max(y))
    i_neg = np.nonzero(y == min(y))
    res_dict['TPR'] = (1 - sm.hamming_loss(y[i_pos], p[i_pos]))*100
    res_dict['TNR'] = (1 - sm.hamming_loss(y[i_neg], p[i_neg]))*100
    res_dict['MAcc'] = np.mean([res_dict['TPR'], res_dict['TNR']])
    res_dict['GM'] = np.sqrt(res_dict['TPR']*res_dict['TNR'])
    res_dict['F1(Macro)'] = sm.f1_score(y, p, average='macro')*100
    res_dict['F1(Micro)'] = sm.f1_score(y, p, average='micro')*100
    res_dict['Acc'] = sm.accuracy_score(y, p)*100
    return res_dict

# %%
def get_dict(d):
    list_final = []
    for i in d:
        list_now = i + '_' + str(d[i])
        list_final.append(list_now)
    return list_final

# %%
if __name__ == '__main__':
    data_name, k_holdout, k_cv, pars = run_Config()
    all_fea, all_label = run_load_data(data_name)
    res_list, opt_pars_list = run_doubleCV(all_fea, all_label, k_holdout, k_cv, pars)
    print 'Each heldout cv result:'
    print '-----------------------'
    for i, j in zip(res_list,opt_pars_list):
        print get_dict(i), 'with hyper-parameters:'
        print get_dict(j)
        print '-----------------------'
# Out:
# Round  1  Holdout CV----------------------
# round  1  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  2  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  3  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  4  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  5  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  6  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  7  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  8  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  9  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  10  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  11  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  12  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  13  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  14  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  15  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  16  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  17  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  18  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  19  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  20  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  21  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  22  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  23  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  24  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  25  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  26  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  27  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  28  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  29  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  30  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  31  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  32  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  33  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  34  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  35  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  36  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  37  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  38  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  39  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  40  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  41  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  42  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  43  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  44  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  45  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  46  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  47  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  48  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  49  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  50  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  51  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  52  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  53  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  54  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  55  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  56  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  57  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  58  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  59  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  60  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  61  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  62  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  63  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  64  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  65  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  66  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  67  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  68  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  69  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  70  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  71  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  72  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  73  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  74  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  75  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  76  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  77  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  78  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  79  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  80  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  81  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  82  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  83  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  84  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  85  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  86  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  87  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  88  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  89  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  90  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  91  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  92  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  93  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  94  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  95  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  96  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  97  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  98  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  99  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  100  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  101  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  102  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  103  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  104  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  105  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  106  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  107  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  108  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  109  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  110  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  111  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  112  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  113  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  114  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  115  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  116  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  117  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  118  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  119  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  120  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  121  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  122  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# round  123  gridsearch cv----------------
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# SMOTE-SVM is running...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-f8a41e218beb> in <module>()
#       2     data_name, k_holdout, k_cv, pars = run_Config()
#       3     all_fea, all_label = run_load_data(data_name)
# ----> 4     res_list, opt_pars_list = run_doubleCV(all_fea, all_label, k_holdout, k_cv, pars)
#       5     print 'Each heldout cv result:'
#       6     print '-----------------------'
#
# <ipython-input-4-e46a0be3b0c0> in run_doubleCV(all_fea, all_label, k_holdout, k_cv, pars)
#      30                 # learn the model
#      31                 # i_pars = {'par_name1':par1,'par_name2':par2,...,'par_nameN':parN}
# ---> 32                 valid_pre, pars_new = run_smote_model(i_pars, train_fea, train_label, valid_fea, 0)
#      33                 grid_score = run_validation(valid_pre, valid_label, i_pars['indicator_name'])
#      34                 pars_score.append(grid_score)
#
# <ipython-input-5-f43d39596592> in run_smote_model(p, X, y, Z, i_tag)
#      12     # run basic model
#      13     clf = SVC(C=p['C'], kernel=p['kernel'], gamma=p['gamma'], class_weight=p['class_weight'])
# ---> 14     clf.fit(X_new,y_new)
#      15     zpre = clf.predict(Z)
#      16     print 'SMOTE-SVM is running...'
#
# //anaconda/envs/tensorflow/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     187
#     188         seed = rnd.randint(np.iinfo('i').max)
# --> 189         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     190         # see comment on the other call to np.iinfo in this file
#     191
#
# //anaconda/envs/tensorflow/lib/python2.7/site-packages/sklearn/svm/base.pyc in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     254                 cache_size=self.cache_size, coef0=self.coef0,
#     255                 gamma=self._gamma, epsilon=self.epsilon,
# --> 256                 max_iter=self.max_iter, random_seed=random_seed)
#     257
#     258         self._warn_from_fit_status()
#
# KeyboardInterrupt:
