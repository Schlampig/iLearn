# %% [markdown]
# ### Binary-class Threshold-based Rule Discovery

# %%
# Basic models
import traceback
import numpy as np
import pandas as pd
import scipy.stats as scs

# Data operation models
from sklearn.model_selection import StratifiedKFold
from sklearn import cross_validation
from sklearn.model_selection import ParameterGrid
from sklearn.preprocessing import LabelEncoder

# Evaluation models
import sklearn.metrics as sm

# %%
# Configurations for the model
def run_Config():
    data_name = 'Thoracic_test.xlsx'
    k_holdout = 5
    k_cv = 5
    origin_pars = {
        'grid_indicator':['GM'],
        'indicator':['F1(Macro)','GM','Acc_Macro'],
        'chi_name': ['p','chi2'],
        'chi_value':[0.05]
    }
    pars = list(ParameterGrid(origin_pars))
    return data_name, k_holdout, k_cv, pars

# %%
# Load data
def run_load_data(data_name):
    all = pd.read_excel(data_name)
    label = all.iloc[:, -1]    # get labels
    data = all.iloc[:, :-1] # get data
    # some preprocessing...
    return data, label

# %%
# Run both HoldoutCV and GridSearchCV
def run_doubleCV(all_fea, all_label, k_holdout, k_cv, pars):
    # HoldoutCV
    i_t = 0
    res_list = []
    opt_pars_list = []
    all_label_num = get_SimpleNumCode(all_label)
    all_fea_num = np.ones(all_label_num.shape)
    
    holdoutcv = StratifiedKFold(n_splits = k_holdout, shuffle = True)
    for i_learn, i_test in holdoutcv.split(all_fea_num, all_label_num):
        # Times
        i_t = i_t + 1
        print 'Round ', str(i_t), ' Holdout CV----------------------'
        
        # Obtain current learning and heldout data
        learn_fea, test_fea = all_fea.iloc[i_learn,:], all_fea.iloc[i_test,:]
        learn_label, test_label = all_label.iloc[i_learn], all_label.iloc[i_test]
        
        # GridSearchCV
        j_t = 0
        optdata = {'score':0}
        for i_pars in pars:
            # times
            j_t = j_t + 1
            print 'round ', str(j_t), ' gridsearch cv----------------'
            pars_score = []
            learn_label_num = get_SimpleNumCode(learn_label)
            learn_fea_num = np.ones(learn_label_num.shape)
            
            gridcv = StratifiedKFold(n_splits = k_cv, shuffle = True)
            for i_train, i_valid in gridcv.split(learn_fea_num, learn_label_num):
                # obtain current training and validation data
                train_fea, valid_fea = learn_fea.iloc[i_train,:], learn_fea.iloc[i_valid,:]
                train_label, valid_label = learn_label.iloc[i_train], learn_label.iloc[i_valid]
                
                # learn the model
                # i_pars = {'par_name1':par1,'par_name2':par2,...,'par_nameN':parN}
                valid_pre, pars_new = run_RuleDiscovery(i_pars, train_fea, train_label, valid_fea)
                eval_dict = get_binary_eval(valid_pre, valid_label)
                grid_score = eval_dict[i_pars['grid_indicator']]
                pars_score.extend([grid_score])
            if np.mean(pars_score) > optdata['score']:
                optdata['pars'] = pars_new
                optdata['score'] = np.mean(pars_score)
        
        # Holdout testing
        # best_pars is a dict too
        best_pars = optdata['pars']
        test_pre, _ = run_RuleDiscovery(best_pars, learn_fea, learn_label, test_fea)
        
        # Evaluate the prediction
        res_now = get_binary_eval(test_pre, test_label)
        
        # Save results
        res_list.append(res_now)
        opt_pars_list.append(best_pars)
        
    return res_list, opt_pars_list

# %%
def get_SimpleNumCode(y):
    clf = LabelEncoder()
    clf.fit(y)
    return clf.transform(y)

# %%
# Run Rule Discovery
def run_RuleDiscovery(p, X, y, Z):
    # train and validate rules
    # v-values, f-features, c-classes, t-thresholds
    # rule = [(v,f,c),(v,f,c),...(v,f,c)]
    # threshold = [(t,c),(t,c),...,(t,c)]
    rule = get_rules(X, y, p)
    pos_rule, threshold, pos_name, neg_name = get_binary_validation(X, y, rule, p)
    print 'run_RuleDiscovery:', ' pos:', pos_name, '; neg:', neg_name
    p['threshold'] = threshold
    
    # test rules
    zpre = get_binary_predict(Z, pos_rule, threshold, pos_name, neg_name)
    
    return zpre, p

# %%
# Train rules
def get_rules(data, label, par):
    fea_name = data.columns.values # get names of features
    rule = []
    for i_f in fea_name:
        square_now = get_square(data[i_f], label)
        chi_tag_now = get_chi_test(square_now.values, par)
        if chi_tag_now == 0: # the current feature would not be considered(selected)
            continue 
        else:
            rule_now = get_fea_rules(square_now, i_f)
        rule.extend(rule_now)
    return rule

def get_square(fea, label):
    # this function is used to generate the contingency table for fea and class_name
    value_name = set(fea)  # get names of current features
    class_name = set(label) # get names of classes
    F = []
    for i_c in class_name:
        f = []
        for i_v in value_name:
            v_index = get_index(fea, i_v) # find index of current value
            c_index = get_index(label, i_c) # find index of current class
            f_v2c = len(set(v_index).intersection(c_index)) # frequence of each value-class pair  
            f.extend([f_v2c])
        F.extend([f])
    F = pd.DataFrame(F, columns = value_name) # transform double list into dataframe
    F = F.rename(lambda x:list(class_name)[x])
    return F

def get_index(lst_now, name_now):
    return [i for i,j in zip(range(len(lst_now)), lst_now) if j == name_now]

def get_chi_test(square, par):
    # this function is used to generate a tag according to threshold
    threshold_value = par['chi_value']
    threshold_name = par['chi_name']
    chi2, p, _, _ = scs.chi2_contingency(square)
    if threshold_name is 'chi2':
        chi_tag = 1 if threshold_value < chi2 else 0
    elif threshold_name is 'p':
        chi_tag = 1 if threshold_value < p else 0 
    return chi_tag

def get_fea_rules(square, fea_name):
    # this function is used to generate rules for each class from the current features 
    wsquare = get_weighted_square(square)
    best_class_name = wsquare.apply(np.argmax, axis = 0)
    rule_fea = [] # rules generated in current feature
    for i, i_v in enumerate(wsquare.columns):
        rule_fea.extend([(i_v, fea_name, best_class_name[i])]) # (value, feature, class)  
    return rule_fea

def get_weighted_square(Z):
    r = Z.apply(np.sum, axis = 1) # summation of columns
    for i in xrange(len(r)):
        Z.ix[i,:] = Z.ix[i,:].apply(lambda x:x/float(r[i])) # ratio of each element
    return Z

# %%
# Valide positive rule in binary-class case
def get_binary_validation(data, label, rule, par):
    # this function is used to determine the optimal threshold for the rule of the positive class
    class_name = list(set(label))
    label_lst = list(label)
    pos_name = class_name[0] if label_lst.count(class_name[0])<=label_lst.count(class_name[1]) else class_name[1]
    neg_name = class_name[0] if class_name[1] == pos_name else class_name[1]
    pos_rule = [(j_v, j_f) for j_v, j_f, j_c in rule if j_c == pos_name] # pos_rule:[(v,f),(v,f),...,(value,fea)]
    upper_fea = len(set([k_f for _,k_f in pos_rule])) # number of features in the rule of the current class
    
    best_res = 0
    threshold = 0 # threshold is a scala
    for i_w in xrange(upper_fea):
        pre_rule_num = get_micro_binary_predict(data, pos_rule)
        pre_label = [pos_name if i_r > i_w else neg_name for i_r in pre_rule_num]
        result_now = get_binary_eval(pre_label, label)
        print 'get_binary_validation:', par['indicator'], '-', result_now[par['indicator']], 'compared with', i_w
        print 'threshold from the last round:', threshold
        print
        if result_now[par['indicator']] > best_res:
            best_res = result_now[par['indicator']]
            threshold = i_w
    return pos_rule, threshold, pos_name, neg_name

def get_micro_binary_predict(data, pos_rule):
    # this function is used to calculate the number of matched rule 
    # (belonging to the same class) for each sample.
    pre_rule_num = []
    for i_data in xrange(len(data.index)):
        sample = zip(data.iloc[i_data,:], data.columns)
        match_num = get_binary_match(sample, pos_rule)
        pre_rule_num.extend([match_num])
    return pre_rule_num

def get_binary_match(sample, pos_rule):
    match_num = 0
    for i_v, i_f in sample:
        for j_v, j_f in pos_rule:
            if i_f == j_f and i_v == j_v:
                match_num = match_num + 1
    return match_num

# %%
# Test rules
def get_binary_predict(Z, pos_rule, threshold, pos_name, neg_name):
    print 'get_binary_predict:', ' pos:', pos_name, '; neg:', neg_name
    zpre = []
    for i in xrange(len(Z.index)):
        Z_i = zip(Z.iloc[i,:], Z.columns)
        #print 'Now:', get_binary_match(Z_i, pos_rule), 'compared with', threshold
        if get_binary_match(Z_i, pos_rule) >= threshold:
            zpre.extend([pos_name])
        else:
            zpre.extend([neg_name])
            
    return zpre

# %%
# Evaluate the performance
def get_binary_eval(p, y):
    # p and y are two list
    res_dict = {}
    
    p_num = get_SimpleNumCode(p)
    y_num = get_SimpleNumCode(y)
    res_dict['F1(Macro)'] = sm.f1_score(y_num, p_num, average='macro')*100
    res_dict['F1(Micro)'] = sm.f1_score(y_num, p_num, average='micro')*100
    res_dict['Acc'] = sm.accuracy_score(y_num, p_num)*100
    
    class_name = set(y)
    acc_each = []
    for i in class_name:
        p_index = get_index(p, i) # find index of current pre_label
        y_index = get_index(y, i) # find index of current true_label    
        acc_p2y = len(set(p_index).intersection(y_index))/float(len(y_index)) * 100 # acc of curren class
        acc_each.extend([(acc_p2y, i)]) # (accuracy, class)     
    res_dict['Acc_Macro'] = np.mean([a for a, c in acc_each])
    res_dict['GM'] = np.sqrt(np.prod([a for a, c in acc_each]))
    res_dict['Acc_each'] = acc_each
    
    return res_dict

# %%
def get_dict(d):
    list_final = []
    for i in d:
        list_now = i + '_' + str(d[i])
        list_final.append(list_now)
    return list_final

# %%
if __name__ == '__main__':
    data_name, k_holdout, k_cv, pars = run_Config()
    all_fea, all_label = run_load_data(data_name)
    res_list, opt_pars_list = run_doubleCV(all_fea, all_label, k_holdout, k_cv, pars)
    print 'Each heldout cv result:'
    print '-----------------------'
    for i, j in zip(res_list,opt_pars_list):
        print get_dict(i), 'with hyper-parameters:'
        print get_dict(j)
        print '-----------------------'
# Out:
# Round  1  Holdout CV----------------------
# round  1  gridsearch cv----------------
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 20.4475524476 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 32.7841624773 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 39.2380865687 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 56.0511839273 compared with 5
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 56.8246716162 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 53.6777091522 compared with 7
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 48.3483483483 compared with 8
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 9
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 10
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 11
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 12
# threshold from the last round: 6
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 18.8480392157 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 35.3207076611 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 53.3597423771 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 56.6246706192 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 57.1316020727 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.4710144928 compared with 7
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 8
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 9
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 10
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 11
# threshold from the last round: 6
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 21.8025579536 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 34.8014440433 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 43.0859303809 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 54.4391669711 compared with 5
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 53.7207872079 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.8633093525 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 9
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 21.5075956812 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 39.1094535797 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 52.3038107106 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 57.8347008205 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 48.9745720459 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.8633093525 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 10
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 18.45910302 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 31.7007028613 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 38.8440539835 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 52.5151803786 compared with 5
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 56.3533834586 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 51.7988683677 compared with 7
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 8
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 9
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 10
# threshold from the last round: 6
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# round  2  gridsearch cv----------------
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 25.4748929429 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 44.8125832065 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 51.5388203202 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 51.5388203202 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 29.3150984989 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: GM - 21.2783901262 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 23.1240615425 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 49.0535421759 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 64.9519052838 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 48.1966458031 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 33.0718913883 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: GM - 14.8779758928 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 25.4814747524 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 44.2432512117 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 54.0061724867 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 63.560448044 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 44.7795526254 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 25.6173769149 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 11
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 30.276503541 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 47.6259295622 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 52.9511042797 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 52.2497341833 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 35.5756236769 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: GM - 14.7901994577 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 23.1240615425 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 44.6436507866 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 52.9511042797 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 59.8391942348 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 50.27701043 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 36.1564885832 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: GM - 14.90711985 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 11
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# round  3  gridsearch cv----------------
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 51.7578125 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 57.4573863636 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 59.0021306818 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 58.8955965909 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 53.7109375 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.7102272727 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 49.4140625 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 52.2092013889 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 57.6649305556 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 58.359375 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 56.2673611111 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 53.5416666667 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 51.8315972222 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 52.5998263889 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 56.8836805556 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 58.6284722222 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 58.9409722222 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 53.9322916667 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.7204861111 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.9157986111 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 52.0138888889 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 57.6041666667 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 60.4600694444 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 61.8359375 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 56.8880208333 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 54.5789930556 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 49.8046875 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 11
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 51.6232638889 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 56.2239583333 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 58.8932291667 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 59.6961805556 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 56.6059027778 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 49.609375 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# round  4  gridsearch cv----------------
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 14.479638009 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 26.9926992699 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 43.5906959469 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 53.0639996491 compared with 5
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 55.9553494442 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 53.194953195 compared with 7
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 47.9166666667 compared with 8
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 9
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 10
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 11
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 12
# threshold from the last round: 6
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 20.670558799 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 34.2612609616 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 40.343386525 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 57.7543859649 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 57.4106827025 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 54.7161172161 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 48.2170785111 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 9
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 10
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 11
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 20.2888552608 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 36.5793023489 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 55.5824702083 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 60.4262948207 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 55.5719557196 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 49.6565958507 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 16.3439124978 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 28.8965913105 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 37.3314628634 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 49.5956105034 compared with 5
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 57.0530804623 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 52.7939126394 compared with 7
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 47.7912684061 compared with 8
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.8633093525 compared with 9
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 10
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 11
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 12
# threshold from the last round: 6
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 19.9049177773 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 32.057183323 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 39.5118316474 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 56.4926253687 compared with 5
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 58.4663906958 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 53.2103271154 compared with 7
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 48.0736055204 compared with 8
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 9
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 10
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 11
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 12
# threshold from the last round: 6
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# round  5  gridsearch cv----------------
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 23.3853586673 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 45.8214946832 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 53.9294046121 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 66.6918158056 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 57.6221528581 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 36.4190806009 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: GM - 15.046093951 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 24.2061459138 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 43.0196983305 compared with 2
# threshold from the last round: 1
#
# get_binary_validation: GM - 54.1826899377 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 60.7748006076 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 43.0297861951 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 14.8779758928 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: GM - 14.90711985 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 25.0 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 46.3793236978 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 53.6837446947 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 66.373051342 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 50.1646594283 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 29.5803989155 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: GM - 14.8779758928 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 27.9508497187 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 45.586456322 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 52.0082792554 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 62.1238681989 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 50.27701043 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 33.0062073287 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: GM - 14.8779758928 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 17.6776695297 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: GM - 38.6400770646 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 49.3006648592 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 61.2372435696 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 55.6838795743 compared with 7
# threshold from the last round: 6
#
# get_binary_validation: GM - 28.9275915962 compared with 8
# threshold from the last round: 6
#
# get_binary_validation: GM - 14.8779758928 compared with 9
# threshold from the last round: 6
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 6
#
# get_binary_validation: GM - 0.0 compared with 11
# threshold from the last round: 6
#
# get_binary_validation: GM - 0.0 compared with 12
# threshold from the last round: 6
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# round  6  gridsearch cv----------------
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 51.171875 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 55.5397727273 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 64.9857954545 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 63.5653409091 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 54.9893465909 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 54.7052556818 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 51.1363636364 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.0 compared with 11
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 53.125 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 59.4965277778 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 60.3255208333 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 64.6440972222 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 61.4670138889 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 55.1041666667 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.9157986111 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.9765625 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 55.7248263889 compared with 2
# threshold from the last round: 1
#
# get_binary_validation: Acc_Macro - 59.5572916667 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 65.6597222222 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 60.8333333333 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 53.3463541667 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 51.4409722222 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.9157986111 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 50.0 compared with 11
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 55.078125 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 64.1319444444 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 60.6857638889 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 56.7404513889 compared with 5
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 50.1345486111 compared with 6
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 50.0 compared with 7
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 50.0 compared with 11
# threshold from the last round: 3
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 54.1015625 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 57.6649305556 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 60.5208333333 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 64.375 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 59.1102430556 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 53.8585069444 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 49.8046875 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.9770114943 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.9770114943 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 20.3974708989 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 32.7885597549 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 39.2964445764 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 55.5407752282 compared with 5
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 57.8212638664 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 53.1131750946 compared with 7
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 47.6895557985 compared with 8
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.9770114943 compared with 9
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.9770114943 compared with 10
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.9770114943 compared with 11
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.9770114943 compared with 12
# threshold from the last round: 6
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# Round  2  Holdout CV----------------------
# round  1  gridsearch cv----------------
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 17.0562848409 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 36.5179415605 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 56.0511839273 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 57.353592319 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 47.7758435498 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 46.0431654676 compared with 9
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 16.8796467103 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 32.3160938002 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 38.7048601683 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 57.3805309735 compared with 5
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 54.9893985046 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 54.9775635699 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.8633093525 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 11
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 18.5644143091 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 38.2751937984 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 55.1228818314 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 57.0176924753 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 47.652173913 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 10
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 20.3809904864 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 40.8833470357 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 56.5745031146 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 48.1672816728 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 45.6678700361 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 8
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.960502693 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 18.45910302 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 36.2856506239 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 51.8245838668 compared with 5
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 54.6155134863 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 53.4488091556 compared with 7
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 8
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 9
# threshold from the last round: 6
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 10
# threshold from the last round: 6
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# round  2  gridsearch cv----------------
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 21.4031911385 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 48.2469676391 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 61.7928747915 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 38.2964661318 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 23.9356776939 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 52.6387056578 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 59.759355381 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 35.3553390593 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 27.3226605179 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: GM - 47.4158611531 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 56.4810071322 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 51.6649865318 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 29.3446947694 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 23.6621181075 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 47.5073093791 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 55.5277708299 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 53.2290647422 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 32.2748612184 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: GM - 14.8779758928 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 6.25 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 33.2812092462 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 62.7495019901 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 42.5734659148 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 25.6681547188 compared with 6
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 7
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 4
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 4
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# round  3  gridsearch cv----------------
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 51.5980113636 compared with 2
# ...
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 18.7394020527 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 32.675613429 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 40.7480314961 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 58.147566719 compared with 5
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 56.5891472868 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 50.5842588122 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 48.0736055204 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.960502693 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# round  5  gridsearch cv----------------
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 23.3853586673 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 46.3416628522 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 55.5831686427 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 68.0752007308 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 51.7451139547 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 21.0265659886 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: GM - 15.046093951 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 23.3853586673 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 45.4338652451 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 57.5316941636 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 69.2218655243 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 51.2770931097 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 25.5664982611 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: GM - 14.8779758928 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 11
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 18.75 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 39.5942967273 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 51.9414734742 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 68.3130051064 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 61.9559655454 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 35.6487493937 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: GM - 20.9165006634 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: GM - 14.8779758928 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 26.5165042945 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 47.5438394187 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 55.6448934464 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 70.5139860044 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 52.7540151184 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 25.5664982611 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 11
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: GM - 0.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: GM - 0.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: GM - 25.7694101601 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: GM - 45.8238626579 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: GM - 56.2114065135 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: GM - 68.4272728279 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: GM - 48.8407275403 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: GM - 14.6723473847 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: GM - 0.0 compared with 11
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# round  6  gridsearch cv----------------
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 53.125 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 57.3686079545 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 62.2514204545 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 71.7151988636 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 61.3813920455 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 51.8465909091 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.9410511364 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 51.171875 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 55.3949652778 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 60.2039930556 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 69.8220486111 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 58.2552083333 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 51.8315972222 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 51.1111111111 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 53.125 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 58.0555555556 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 63.2552083333 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 70.6380208333 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 62.3697916667 compared with 7
# threshold from the last round: 6
#
# get_binary_validation: Acc_Macro - 52.5520833333 compared with 8
# threshold from the last round: 6
#
# get_binary_validation: Acc_Macro - 50.9157986111 compared with 9
# threshold from the last round: 6
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 6
#
# get_binary_validation: Acc_Macro - 50.0 compared with 11
# threshold from the last round: 6
#
# get_binary_validation: Acc_Macro - 50.0 compared with 12
# threshold from the last round: 6
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 52.9296875 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 58.1293402778 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 63.0729166667 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 67.5130208333 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 62.1137152778 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.6597222222 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 49.8046875 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 51.953125 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: Acc_Macro - 53.9539930556 compared with 3
# threshold from the last round: 2
#
# get_binary_validation: Acc_Macro - 60.0694444444 compared with 4
# threshold from the last round: 3
#
# get_binary_validation: Acc_Macro - 68.8585069444 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: Acc_Macro - 63.7022569444 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 55.4340277778 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 51.4409722222 compared with 8
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.9157986111 compared with 9
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 10
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 11
# threshold from the last round: 5
#
# get_binary_validation: Acc_Macro - 50.0 compared with 12
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# get_binary_validation: F1(Macro) - 45.9770114943 compared with 0
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 45.9770114943 compared with 1
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 20.5379442843 compared with 2
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 40.5063291139 compared with 3
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 55.088389871 compared with 4
# threshold from the last round: 0
#
# get_binary_validation: F1(Macro) - 55.4575163399 compared with 5
# threshold from the last round: 4
#
# get_binary_validation: F1(Macro) - 45.9770114943 compared with 6
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.9770114943 compared with 7
# threshold from the last round: 5
#
# get_binary_validation: F1(Macro) - 45.9770114943 compared with 8
# threshold from the last round: 5
#
# run_RuleDiscovery:  pos: T ; neg: F
# get_binary_predict:  pos: T ; neg: F
# Each heldout cv result:
# -----------------------
# ['Acc_74.4680851064', 'F1(Micro)_74.4680851064', 'Acc_Macro_79.1071428571', 'F1(Macro)_66.4285714286', 'GM_78.8307409218', "Acc_each_[(85.71428571428571, u'T'), (72.5, u'F')]"] with hyper-parameters:
# ['chi_name_chi2', 'chi_value_0.05', 'indicator_F1(Macro)', 'grid_indicator_GM', 'threshold_5']
# -----------------------
# ['Acc_53.1914893617', 'F1(Micro)_53.1914893617', 'Acc_Macro_69.5535714286', 'F1(Macro)_49.9273607748', 'GM_65.5335246812', "Acc_each_[(92.85714285714286, u'T'), (46.25, u'F')]"] with hyper-parameters:
# ['chi_name_chi2', 'chi_value_0.05', 'indicator_F1(Macro)', 'grid_indicator_GM', 'threshold_5']
# -----------------------
# ['Acc_68.085106383', 'F1(Micro)_68.085106383', 'Acc_Macro_60.625', 'F1(Macro)_55.4924242424', 'GM_59.6866819316', "Acc_each_[(50.0, u'T'), (71.25, u'F')]"] with hyper-parameters:
# ['chi_name_chi2', 'chi_value_0.05', 'indicator_F1(Macro)', 'grid_indicator_GM', 'threshold_5']
# -----------------------
# ['Acc_68.085106383', 'F1(Micro)_68.085106383', 'Acc_Macro_54.7321428571', 'F1(Macro)_52.3648648649', 'GM_51.3218137971', "Acc_each_[(35.714285714285715, u'T'), (73.75, u'F')]"] with hyper-parameters:
# ['chi_name_chi2', 'chi_value_0.05', 'indicator_F1(Macro)', 'grid_indicator_GM', 'threshold_5']
# -----------------------
# ['Acc_71.2765957447', 'F1(Micro)_71.2765957447', 'Acc_Macro_59.5535714286', 'F1(Macro)_56.3242127001', 'GM_57.1651742135', "Acc_each_[(42.857142857142854, u'T'), (76.25, u'F')]"] with hyper-parameters:
# ['chi_name_p', 'chi_value_0.05', 'indicator_F1(Macro)', 'grid_indicator_GM', 'threshold_5']
# -----------------------
