# %% [markdown]
# ### Multi-class Threshold-based Rule Discovery

# %%
# Basic models
import traceback
import numpy as np
import pandas as pd
import scipy.stats as scs

# Data operation models
from sklearn.model_selection import StratifiedKFold
from sklearn import cross_validation
from sklearn.model_selection import ParameterGrid
from sklearn.preprocessing import LabelEncoder

# Evaluation models
import sklearn.metrics as sm
# Out:
# //anaconda/envs/tensorflow/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Configurations for the model
def run_Config():
    data_name = 'Thoracic_test.xlsx'
    k_holdout = 5
    k_cv = 5
    origin_pars = {
        'indicator_name':['Acc_Macro'],
        'indicator':['Acc_Macro'],
        'chi_name': ['p','chi2'],
        'chi_value':[0.05]
    }
    pars = list(ParameterGrid(origin_pars))
    return data_name, k_holdout, k_cv, pars

# %%
# Load data
def run_load_data(data_name):
    all = pd.read_excel(data_name)
    label = all.iloc[:, -1]    # get labels
    data = all.iloc[:, :-1] # get data
    # some preprocessing...
    return data, label

# %%
# Run both HoldoutCV and GridSearchCV
def run_doubleCV(all_fea, all_label, k_holdout, k_cv, pars):
    # HoldoutCV
    i_t = 0
    res_list = []
    opt_pars_list = []
    all_label_num = get_SimpleNumCode(all_label)
    all_fea_num = np.ones(all_label_num.shape)
    
    holdoutcv = StratifiedKFold(n_splits = k_holdout, shuffle = True)
    for i_learn, i_test in holdoutcv.split(all_fea_num, all_label_num):
        # Times
        i_t = i_t + 1
        print 'Round ', str(i_t), ' Holdout CV----------------------'
        
        # Obtain current learning and heldout data
        learn_fea, test_fea = all_fea.iloc[i_learn,:], all_fea.iloc[i_test,:]
        learn_label, test_label = all_label.iloc[i_learn], all_label.iloc[i_test]
        
        # GridSearchCV
        j_t = 0
        optdata = {'score':0}
        for i_pars in pars:
            # times
            j_t = j_t + 1
            print 'round ', str(j_t), ' gridsearch cv----------------'
            pars_score = []
            learn_label_num = get_SimpleNumCode(learn_label)
            learn_fea_num = np.ones(learn_label_num.shape)
            
            gridcv = StratifiedKFold(n_splits = k_cv, shuffle = True)
            for i_train, i_valid in gridcv.split(learn_fea_num, learn_label_num):
                # obtain current training and validation data
                train_fea, valid_fea = learn_fea.iloc[i_train,:], learn_fea.iloc[i_valid,:]
                train_label, valid_label = learn_label.iloc[i_train], learn_label.iloc[i_valid]
                
                # learn the model
                # i_pars = {'par_name1':par1,'par_name2':par2,...,'par_nameN':parN}
                valid_pre, pars_new = run_RuleDiscovery(i_pars, train_fea, train_label, valid_fea)
                eval_dict = run_evaluation(valid_pre, valid_label)
                grid_score = eval_dict[i_pars['indicator_name']]
                pars_score.extend([grid_score])
            if np.mean(pars_score) > optdata['score']:
                optdata['pars'] = pars_new
                optdata['score'] = np.mean(pars_score)
        
        # Holdout testing
        # best_pars is a dict too
        best_pars = optdata['pars']
        test_pre, _ = run_RuleDiscovery(best_pars, learn_fea, learn_label, test_fea)
        
        # Evaluate the prediction
        res_now = run_evaluation(test_pre, test_label)
        
        # Save results
        res_list.append(res_now)
        opt_pars_list.append(best_pars)
        
    return res_list, opt_pars_list

# %%
def get_SimpleNumCode(y):
    clf = LabelEncoder()
    clf.fit(y)
    return clf.transform(y)

# %%
# Run Rule Discovery
def run_RuleDiscovery(p, X, y, Z):
    # train and validate rules
    # v-values, f-features, c-classes, t-thresholds
    # rule = [(v,f,c),(v,f,c),...(v,f,c)]
    # threshold = [(t,c),(t,c),...,(t,c)]
    rule = get_rules(X, y, p)
    threshold = get_validation(X, y, rule, p)
    p['threshold'] = threshold
    
    # test rules
    zpre = get_rule_predict(Z, rule, threshold)
    
    return zpre, p

# %%
# Train rules
def get_rules(data, label, par):
    fea_name = data.columns.values # get names of features
    rule = []
    for i_f in fea_name:
        square_now = get_square(data[i_f], label)
        chi_tag_now = get_chi_test(square_now.values, par)
        if chi_tag_now == 0: # the current feature would not be considered(selected)
            continue 
        else:
            rule_now = get_fea_rules(square_now, i_f)
        rule.extend(rule_now)
    return rule # rule is a list with structure like: rule = [iterm1, iterm2, ..., itermN], where itermi = (value, feature, class) 

def get_square(fea, label):
    # this function is used to generate the contingency table for fea and class_name
    value_name = set(fea)  # get names of current features
    class_name = set(label) # get names of classes
    F = []
    for i_c in class_name:
        f = []
        for i_v in value_name:
            v_index = get_index(fea, i_v) # find index of current value
            c_index = get_index(label, i_c) # find index of current class
            f_v2c = len(set(v_index).intersection(c_index)) # frequence of each value-class pair  
            f.extend([f_v2c])
        F.extend([f])
    F = pd.DataFrame(F, columns = value_name) # transform double list into dataframe
    F = F.rename(lambda x:list(class_name)[x])
    return F

def get_index(lst_now, name_now):
    return [i for i,j in zip(range(len(lst_now)), lst_now) if j == name_now]

def get_chi_test(square, par):
    # this function is used to generate a tag according to threshold
    threshold_value = par['chi_value']
    threshold_name = par['chi_name']
    chi2, p, _, _ = scs.chi2_contingency(square)
    if threshold_name is 'chi2':
        chi_tag = 1 if threshold_value < chi2 else 0
    elif threshold_name is 'p':
        chi_tag = 1 if threshold_value < p else 0 
    return chi_tag

def get_fea_rules(square, fea_name):
    # this function is used to generate rules for each class from the current features 
    wsquare = get_weighted_square(square)
    best_class_name = wsquare.apply(np.argmax, axis = 0)
    rule_fea = [] # rules generated in current feature
    for i, i_v in enumerate(wsquare.columns):
        rule_fea.extend([(i_v, fea_name, best_class_name[i])]) # (value, feature, class)  
    return rule_fea

def get_weighted_square(Z):
    r = Z.apply(np.sum, axis = 1) # summation of columns
    for i in xrange(len(r)):
        Z.ix[i,:] = Z.ix[i,:].apply(lambda x:x/float(r[i])) # ratio of each element
    return Z

# %%
# Valide rules
def get_validation(data, label, rule, par):
    # this function is used to determine the optimal threshold for each rule of the class
    threshold = {}
    class_rule = {}
    class_name = set(label)
    for i_c in class_name:
        class_rule[i_c] = [(j_v, j_f, j_c) for j_v, j_f, j_c in rule if j_c == i_c] # rules of the current class
        threshold[i_c] = range(len(set([k_f for _,k_f,_ in class_rule[i_c]]))) # number of features in the rule of the current class
    threshold_grid = list(ParameterGrid(threshold))
    print threshold_grid
    print
    
    best_res = 0
    best_threshold = None
    for i_t in threshold_grid:
        pre_now = {}
        for c in class_name: # each class makes a prediction for the data
            threshold_now = i_t[c]
            pre_rule_num = get_micro_predict(data, class_rule[c])
            pre_now[c] = [c if i_r > threshold_now else None for i_r in pre_rule_num]
        pre_label = get_voted_pre(pre_now)
        result_now = run_evaluation(pre_label, label)
        print 'get_validation:', par['indicator'], '-', result_now[par['indicator']], 'compared with', threshold_now
        print 'threshold from the last round:', threshold_now
        print
        if result_now[par['indicator']] > best_res:
            best_res = result_now[par['indicator']]
            best_threshold = i_t # i_t is a dict with sturcture like i_t = {c1: threshold1, c2: threshold2, ..., cN:thresholdN}
    return best_threshold

def get_micro_predict(data, rule):
    # this function is used to calculate the number of matched rule 
    # (belonging to the same class) for each sample.
    pre_rule_num = []
    for i_data in xrange(len(data.index)):
        sample = zip(data.iloc[i_data,:], data.columns)
        match_num = get_match(sample, rule)
        pre_rule_num.extend([match_num])
    return pre_rule_num

def get_match(sample, rule):
    match_num = 0
    for i_v, i_f in sample:
        for j_v, j_f, _ in rule:
            if i_f == j_f and i_v == j_v:
                match_num = match_num + 1
    return match_num

def get_voted_pre(pdict):
    tempor_list = [[j for j in pdict[i]] for i in pdict]
    N = len(tempor_list[0])
    plist = [[n[m] for n in tempor_list] for m in xrange(N)]
    return [max(k, key = k.count) for k in plist]

# %%
# Test rules
def get_rule_predict(Z, rule, threshold):
    class_name = set([c for _, _, c in rule])
    zpre = []
    for i in xrange(len(Z.index)):
        Z_i = zip(Z.iloc[i,:], Z.columns)
        vote = []
        for j in class_name:
            rule_now = [(v,f,c) for v, f, c in rule if c == j]
            threshold_now = threshold[j]
            print 'Now:', get_match(Z_i, rule_now), 'compared with', threshold_now, ' | ', j
            if get_match(Z_i, rule_now) >= threshold_now:
                vote.extend([j])
        zpre.extend([max(vote, key = vote.count)])
    return zpre

# %%
# Evaluate the performance
def run_evaluation(p, y):
    # p and y are two list
    res_dict = {}
    acc_each = []
    class_name = set(y)
    for i in class_name:
        p_index = get_index(p, i) # find index of current pre_label
        y_index = get_index(y, i) # find index of current true_label    
        acc_p2y = len(set(p_index).intersection(y_index))/float(len(y_index)) * 100 # acc of curren class
        acc_each.extend([(acc_p2y, i)]) # (accuracy, class)     
    res_dict['Acc_Macro'] = np.mean([a for a, c in acc_each])
    res_dict['Acc_each'] = acc_each
    return res_dict

# %%
def get_dict(d):
    list_final = []
    for i in d:
        list_now = i + '_' + str(d[i])
        list_final.append(list_now)
    return list_final

# %%
if __name__ == '__main__':
    data_name, k_holdout, k_cv, pars = run_Config()
    all_fea, all_label = run_load_data(data_name)
    res_list, opt_pars_list = run_doubleCV(all_fea, all_label, k_holdout, k_cv, pars)
    print 'Each heldout cv result:'
    print '-----------------------'
    for i, j in zip(res_list,opt_pars_list):
        print get_dict(i), 'with hyper-parameters:'
        print get_dict(j)
        print '-----------------------'
# Out:
# Round  1  Holdout CV----------------------
# round  1  gridsearch cv----------------
# [{u'T': 0, u'F': 0}, {u'T': 1, u'F': 0}, {u'T': 2, u'F': 0}, {u'T': 3, u'F': 0}, {u'T': 4, u'F': 0}, {u'T': 5, u'F': 0}, {u'T': 6, u'F': 0}, {u'T': 7, u'F': 0}, {u'T': 8, u'F': 0}, {u'T': 9, u'F': 0}, {u'T': 0, u'F': 1}, {u'T': 1, u'F': 1}, {u'T': 2, u'F': 1}, {u'T': 3, u'F': 1}, {u'T': 4, u'F': 1}, {u'T': 5, u'F': 1}, {u'T': 6, u'F': 1}, {u'T': 7, u'F': 1}, {u'T': 8, u'F': 1}, {u'T': 9, u'F': 1}, {u'T': 0, u'F': 2}, {u'T': 1, u'F': 2}, {u'T': 2, u'F': 2}, {u'T': 3, u'F': 2}, {u'T': 4, u'F': 2}, {u'T': 5, u'F': 2}, {u'T': 6, u'F': 2}, {u'T': 7, u'F': 2}, {u'T': 8, u'F': 2}, {u'T': 9, u'F': 2}, {u'T': 0, u'F': 3}, {u'T': 1, u'F': 3}, {u'T': 2, u'F': 3}, {u'T': 3, u'F': 3}, {u'T': 4, u'F': 3}, {u'T': 5, u'F': 3}, {u'T': 6, u'F': 3}, {u'T': 7, u'F': 3}, {u'T': 8, u'F': 3}, {u'T': 9, u'F': 3}, {u'T': 0, u'F': 4}, {u'T': 1, u'F': 4}, {u'T': 2, u'F': 4}, {u'T': 3, u'F': 4}, {u'T': 4, u'F': 4}, {u'T': 5, u'F': 4}, {u'T': 6, u'F': 4}, {u'T': 7, u'F': 4}, {u'T': 8, u'F': 4}, {u'T': 9, u'F': 4}, {u'T': 0, u'F': 5}, {u'T': 1, u'F': 5}, {u'T': 2, u'F': 5}, {u'T': 3, u'F': 5}, {u'T': 4, u'F': 5}, {u'T': 5, u'F': 5}, {u'T': 6, u'F': 5}, {u'T': 7, u'F': 5}, {u'T': 8, u'F': 5}, {u'T': 9, u'F': 5}, {u'T': 0, u'F': 6}, {u'T': 1, u'F': 6}, {u'T': 2, u'F': 6}, {u'T': 3, u'F': 6}, {u'T': 4, u'F': 6}, {u'T': 5, u'F': 6}, {u'T': 6, u'F': 6}, {u'T': 7, u'F': 6}, {u'T': 8, u'F': 6}, {u'T': 9, u'F': 6}, {u'T': 0, u'F': 7}, {u'T': 1, u'F': 7}, {u'T': 2, u'F': 7}, {u'T': 3, u'F': 7}, {u'T': 4, u'F': 7}, {u'T': 5, u'F': 7}, {u'T': 6, u'F': 7}, {u'T': 7, u'F': 7}, {u'T': 8, u'F': 7}, {u'T': 9, u'F': 7}, {u'T': 0, u'F': 8}, {u'T': 1, u'F': 8}, {u'T': 2, u'F': 8}, {u'T': 3, u'F': 8}, {u'T': 4, u'F': 8}, {u'T': 5, u'F': 8}, {u'T': 6, u'F': 8}, {u'T': 7, u'F': 8}, {u'T': 8, u'F': 8}, {u'T': 9, u'F': 8}, {u'T': 0, u'F': 9}, {u'T': 1, u'F': 9}, {u'T': 2, u'F': 9}, {u'T': 3, u'F': 9}, {u'T': 4, u'F': 9}, {u'T': 5, u'F': 9}, {u'T': 6, u'F': 9}, {u'T': 7, u'F': 9}, {u'T': 8, u'F': 9}, {u'T': 9, u'F': 9}]
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 44.3181818182 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 27.2727272727 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 5.68181818182 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 44.3181818182 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 27.2727272727 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 5.68181818182 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 44.3181818182 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 27.2727272727 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 5.68181818182 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 44.3181818182 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 27.2727272727 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 5.68181818182 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 44.3181818182 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 27.2727272727 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 5.68181818182 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 44.3181818182 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 27.2727272727 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 5.68181818182 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 44.3181818182 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 27.2727272727 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 5.68181818182 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 0.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 0.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 0.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 50.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 50.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 50.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 50.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 44.3181818182 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 27.2727272727 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 5.68181818182 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 0.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 0.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 0.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 44.3181818182 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 27.2727272727 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 5.68181818182 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 0.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 0.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 0.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 44.3181818182 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 27.2727272727 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 5.68181818182 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 0.0 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 0.0 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 0.0 compared with 9
# threshold from the last round: 9
#
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 8 compared with 0  |  T
# Now: 2 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# [{u'T': 0, u'F': 0}, {u'T': 1, u'F': 0}, {u'T': 2, u'F': 0}, {u'T': 3, u'F': 0}, {u'T': 4, u'F': 0}, {u'T': 5, u'F': 0}, {u'T': 6, u'F': 0}, {u'T': 0, u'F': 1}, {u'T': 1, u'F': 1}, {u'T': 2, u'F': 1}, {u'T': 3, u'F': 1}, {u'T': 4, u'F': 1}, {u'T': 5, u'F': 1}, {u'T': 6, u'F': 1}, {u'T': 0, u'F': 2}, {u'T': 1, u'F': 2}, {u'T': 2, u'F': 2}, {u'T': 3, u'F': 2}, {u'T': 4, u'F': 2}, {u'T': 5, u'F': 2}, {u'T': 6, u'F': 2}, {u'T': 0, u'F': 3}, {u'T': 1, u'F': 3}, {u'T': 2, u'F': 3}, {u'T': 3, u'F': 3}, {u'T': 4, u'F': 3}, {u'T': 5, u'F': 3}, {u'T': 6, u'F': 3}, {u'T': 0, u'F': 4}, {u'T': 1, u'F': 4}, {u'T': 2, u'F': 4}, {u'T': 3, u'F': 4}, {u'T': 4, u'F': 4}, {u'T': 5, u'F': 4}, {u'T': 6, u'F': 4}, {u'T': 0, u'F': 5}, {u'T': 1, u'F': 5}, {u'T': 2, u'F': 5}, {u'T': 3, u'F': 5}, {u'T': 4, u'F': 5}, {u'T': 5, u'F': 5}, {u'T': 6, u'F': 5}, {u'T': 0, u'F': 6}, {u'T': 1, u'F': 6}, {u'T': 2, u'F': 6}, {u'T': 3, u'F': 6}, {u'T': 4, u'F': 6}, {u'T': 5, u'F': 6}, {u'T': 6, u'F': 6}]
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 46.6666666667 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 21.1111111111 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 5.55555555556 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 46.6666666667 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 21.1111111111 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 5.55555555556 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 46.6666666667 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 21.1111111111 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 5.55555555556 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 46.6666666667 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 21.1111111111 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 5.55555555556 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 46.6666666667 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 21.1111111111 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 5.55555555556 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 46.6666666667 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 21.1111111111 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 5.55555555556 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 46.6666666667 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 21.1111111111 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 5.55555555556 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 0.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 0.0 compared with 6
# threshold from the last round: 6
#
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 2 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 2 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 1 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 2 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 2 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 2 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 4 compared with 0  |  F
# [{u'T': 0, u'F': 0}, {u'T': 1, u'F': 0}, {u'T': 2, u'F': 0}, {u'T': 3, u'F': 0}, {u'T': 4, u'F': 0}, {u'T': 5, u'F': 0}, {u'T': 6, u'F': 0}, {u'T': 7, u'F': 0}, {u'T': 8, u'F': 0}, {u'T': 9, u'F': 0}, {u'T': 0, u'F': 1}, {u'T': 1, u'F': 1}, {u'T': 2, u'F': 1}, {u'T': 3, u'F': 1}, {u'T': 4, u'F': 1}, {u'T': 5, u'F': 1}, {u'T': 6, u'F': 1}, {u'T': 7, u'F': 1}, {u'T': 8, u'F': 1}, {u'T': 9, u'F': 1}, {u'T': 0, u'F': 2}, {u'T': 1, u'F': 2}, {u'T': 2, u'F': 2}, {u'T': 3, u'F': 2}, {u'T': 4, u'F': 2}, {u'T': 5, u'F': 2}, {u'T': 6, u'F': 2}, {u'T': 7, u'F': 2}, {u'T': 8, u'F': 2}, {u'T': 9, u'F': 2}, {u'T': 0, u'F': 3}, {u'T': 1, u'F': 3}, {u'T': 2, u'F': 3}, {u'T': 3, u'F': 3}, {u'T': 4, u'F': 3}, {u'T': 5, u'F': 3}, {u'T': 6, u'F': 3}, {u'T': 7, u'F': 3}, {u'T': 8, u'F': 3}, {u'T': 9, u'F': 3}, {u'T': 0, u'F': 4}, {u'T': 1, u'F': 4}, {u'T': 2, u'F': 4}, {u'T': 3, u'F': 4}, {u'T': 4, u'F': 4}, {u'T': 5, u'F': 4}, {u'T': 6, u'F': 4}, {u'T': 7, u'F': 4}, {u'T': 8, u'F': 4}, {u'T': 9, u'F': 4}, {u'T': 0, u'F': 5}, {u'T': 1, u'F': 5}, {u'T': 2, u'F': 5}, {u'T': 3, u'F': 5}, {u'T': 4, u'F': 5}, {u'T': 5, u'F': 5}, {u'T': 6, u'F': 5}, {u'T': 7, u'F': 5}, {u'T': 8, u'F': 5}, {u'T': 9, u'F': 5}, {u'T': 0, u'F': 6}, {u'T': 1, u'F': 6}, {u'T': 2, u'F': 6}, {u'T': 3, u'F': 6}, {u'T': 4, u'F': 6}, {u'T': 5, u'F': 6}, {u'T': 6, u'F': 6}, {u'T': 7, u'F': 6}, {u'T': 8, u'F': 6}, {u'T': 9, u'F': 6}, {u'T': 0, u'F': 7}, {u'T': 1, u'F': 7}, {u'T': 2, u'F': 7}, {u'T': 3, u'F': 7}, {u'T': 4, u'F': 7}, {u'T': 5, u'F': 7}, {u'T': 6, u'F': 7}, {u'T': 7, u'F': 7}, {u'T': 8, u'F': 7}, {u'T': 9, u'F': 7}, {u'T': 0, u'F': 8}, {u'T': 1, u'F': 8}, {u'T': 2, u'F': 8}, {u'T': 3, u'F': 8}, {u'T': 4, u'F': 8}, {u'T': 5, u'F': 8}, {u'T': 6, u'F': 8}, {u'T': 7, u'F': 8}, {u'T': 8, u'F': 8}, {u'T': 9, u'F': 8}, {u'T': 0, u'F': 9}, {u'T': 1, u'F': 9}, {u'T': 2, u'F': 9}, {u'T': 3, u'F': 9}, {u'T': 4, u'F': 9}, {u'T': 5, u'F': 9}, {u'T': 6, u'F': 9}, {u'T': 7, u'F': 9}, {u'T': 8, u'F': 9}, {u'T': 9, u'F': 9}]
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 47.7777777778 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 43.3333333333 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 38.8888888889 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 17.7777777778 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 7.77777777778 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 47.7777777778 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 43.3333333333 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 38.8888888889 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 17.7777777778 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 7.77777777778 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 47.7777777778 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 43.3333333333 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 38.8888888889 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 17.7777777778 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 7.77777777778 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 47.7777777778 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 43.3333333333 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 38.8888888889 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 17.7777777778 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 7.77777777778 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 47.7777777778 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 43.3333333333 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 38.8888888889 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 17.7777777778 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 7.77777777778 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 47.7777777778 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 43.3333333333 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 38.8888888889 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 17.7777777778 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 7.77777777778 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 47.7777777778 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 43.3333333333 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 38.8888888889 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 17.7777777778 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 7.77777777778 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 0.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 0.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 0.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 50.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 50.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 47.7777777778 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 43.3333333333 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 38.8888888889 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 17.7777777778 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 7.77777777778 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 0.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 0.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 0.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 47.7777777778 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 43.3333333333 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 38.8888888889 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 17.7777777778 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 7.77777777778 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 0.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 0.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 0.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 50.0 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 47.7777777778 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 43.3333333333 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 38.8888888889 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 17.7777777778 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 7.77777777778 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 0.0 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 0.0 compared with 9
# threshold from the last round: 9
#
# get_validation: Acc_Macro - 0.0 compared with 9
# threshold from the last round: 9
#
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 8 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 8 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 8 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 3 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 4 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 5 compared with 0  |  F
# [{u'T': 0, u'F': 0}, {u'T': 1, u'F': 0}, {u'T': 2, u'F': 0}, {u'T': 3, u'F': 0}, {u'T': 4, u'F': 0}, {u'T': 5, u'F': 0}, {u'T': 6, u'F': 0}, {u'T': 7, u'F': 0}, {u'T': 8, u'F': 0}, {u'T': 9, u'F': 0}, {u'T': 10, u'F': 0}, {u'T': 0, u'F': 1}, {u'T': 1, u'F': 1}, {u'T': 2, u'F': 1}, {u'T': 3, u'F': 1}, {u'T': 4, u'F': 1}, {u'T': 5, u'F': 1}, {u'T': 6, u'F': 1}, {u'T': 7, u'F': 1}, {u'T': 8, u'F': 1}, {u'T': 9, u'F': 1}, {u'T': 10, u'F': 1}, {u'T': 0, u'F': 2}, {u'T': 1, u'F': 2}, {u'T': 2, u'F': 2}, {u'T': 3, u'F': 2}, {u'T': 4, u'F': 2}, {u'T': 5, u'F': 2}, {u'T': 6, u'F': 2}, {u'T': 7, u'F': 2}, {u'T': 8, u'F': 2}, {u'T': 9, u'F': 2}, {u'T': 10, u'F': 2}, {u'T': 0, u'F': 3}, {u'T': 1, u'F': 3}, {u'T': 2, u'F': 3}, {u'T': 3, u'F': 3}, {u'T': 4, u'F': 3}, {u'T': 5, u'F': 3}, {u'T': 6, u'F': 3}, {u'T': 7, u'F': 3}, {u'T': 8, u'F': 3}, {u'T': 9, u'F': 3}, {u'T': 10, u'F': 3}, {u'T': 0, u'F': 4}, {u'T': 1, u'F': 4}, {u'T': 2, u'F': 4}, {u'T': 3, u'F': 4}, {u'T': 4, u'F': 4}, {u'T': 5, u'F': 4}, {u'T': 6, u'F': 4}, {u'T': 7, u'F': 4}, {u'T': 8, u'F': 4}, {u'T': 9, u'F': 4}, {u'T': 10, u'F': 4}, {u'T': 0, u'F': 5}, {u'T': 1, u'F': 5}, {u'T': 2, u'F': 5}, {u'T': 3, u'F': 5}, {u'T': 4, u'F': 5}, {u'T': 5, u'F': 5}, {u'T': 6, u'F': 5}, {u'T': 7, u'F': 5}, {u'T': 8, u'F': 5}, {u'T': 9, u'F': 5}, {u'T': 10, u'F': 5}, {u'T': 0, u'F': 6}, {u'T': 1, u'F': 6}, {u'T': 2, u'F': 6}, {u'T': 3, u'F': 6}, {u'T': 4, u'F': 6}, {u'T': 5, u'F': 6}, {u'T': 6, u'F': 6}, {u'T': 7, u'F': 6}, {u'T': 8, u'F': 6}, {u'T': 9, u'F': 6}, {u'T': 10, u'F': 6}, {u'T': 0, u'F': 7}, {u'T': 1, u'F': 7}, {u'T': 2, u'F': 7}, {u'T': 3, u'F': 7}, {u'T': 4, u'F': 7}, {u'T': 5, u'F': 7}, {u'T': 6, u'F': 7}, {u'T': 7, u'F': 7}, {u'T': 8, u'F': 7}, {u'T': 9, u'F': 7}, {u'T': 10, u'F': 7}, {u'T': 0, u'F': 8}, {u'T': 1, u'F': 8}, {u'T': 2, u'F': 8}, {u'T': 3, u'F': 8}, {u'T': 4, u'F': 8}, {u'T': 5, u'F': 8}, {u'T': 6, u'F': 8}, {u'T': 7, u'F': 8}, {u'T': 8, u'F': 8}, {u'T': 9, u'F': 8}, {u'T': 10, u'F': 8}, {u'T': 0, u'F': 9}, {u'T': 1, u'F': 9}, {u'T': 2, u'F': 9}, {u'T': 3, u'F': 9}, {u'T': 4, u'F': 9}, {u'T': 5, u'F': 9}, {u'T': 6, u'F': 9}, {u'T': 7, u'F': 9}, {u'T': 8, u'F': 9}, {u'T': 9, u'F': 9}, {u'T': 10, u'F': 9}, {u'T': 0, u'F': 10}, {u'T': 1, u'F': 10}, {u'T': 2, u'F': 10}, {u'T': 3, u'F': 10}, {u'T': 4, u'F': 10}, {u'T': 5, u'F': 10}, {u'T': 6, u'F': 10}, {u'T': 7, u'F': 10}, {u'T': 8, u'F': 10}, {u'T': 9, u'F': 10}, {u'T': 10, u'F': 10}]
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 48.8888888889 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 43.3333333333 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 40.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 24.4444444444 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 7.77777777778 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 3.33333333333 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 1.11111111111 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 48.8888888889 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 43.3333333333 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 40.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 24.4444444444 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 7.77777777778 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 3.33333333333 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 1.11111111111 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 48.8888888889 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 43.3333333333 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 40.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 24.4444444444 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 7.77777777778 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 3.33333333333 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 1.11111111111 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 48.8888888889 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 43.3333333333 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 40.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 24.4444444444 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 7.77777777778 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 3.33333333333 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 1.11111111111 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 48.8888888889 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 43.3333333333 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 40.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 24.4444444444 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 7.77777777778 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 3.33333333333 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 1.11111111111 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 48.8888888889 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 43.3333333333 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 40.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 24.4444444444 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 7.77777777778 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 3.33333333333 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 1.11111111111 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# ...
# Now: 5 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 9 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 10 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 9 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 9 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 8 compared with 0  |  T
# Now: 4 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 9 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 10 compared with 0  |  F
# Now: 2 compared with 0  |  T
# Now: 10 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 9 compared with 0  |  F
# Now: 6 compared with 0  |  T
# Now: 6 compared with 0  |  F
# Now: 7 compared with 0  |  T
# Now: 5 compared with 0  |  F
# Now: 5 compared with 0  |  T
# Now: 7 compared with 0  |  F
# Now: 3 compared with 0  |  T
# Now: 9 compared with 0  |  F
# [{u'T': 0, u'F': 0}, {u'T': 1, u'F': 0}, {u'T': 2, u'F': 0}, {u'T': 3, u'F': 0}, {u'T': 4, u'F': 0}, {u'T': 5, u'F': 0}, {u'T': 6, u'F': 0}, {u'T': 7, u'F': 0}, {u'T': 8, u'F': 0}, {u'T': 9, u'F': 0}, {u'T': 10, u'F': 0}, {u'T': 11, u'F': 0}, {u'T': 0, u'F': 1}, {u'T': 1, u'F': 1}, {u'T': 2, u'F': 1}, {u'T': 3, u'F': 1}, {u'T': 4, u'F': 1}, {u'T': 5, u'F': 1}, {u'T': 6, u'F': 1}, {u'T': 7, u'F': 1}, {u'T': 8, u'F': 1}, {u'T': 9, u'F': 1}, {u'T': 10, u'F': 1}, {u'T': 11, u'F': 1}, {u'T': 0, u'F': 2}, {u'T': 1, u'F': 2}, {u'T': 2, u'F': 2}, {u'T': 3, u'F': 2}, {u'T': 4, u'F': 2}, {u'T': 5, u'F': 2}, {u'T': 6, u'F': 2}, {u'T': 7, u'F': 2}, {u'T': 8, u'F': 2}, {u'T': 9, u'F': 2}, {u'T': 10, u'F': 2}, {u'T': 11, u'F': 2}, {u'T': 0, u'F': 3}, {u'T': 1, u'F': 3}, {u'T': 2, u'F': 3}, {u'T': 3, u'F': 3}, {u'T': 4, u'F': 3}, {u'T': 5, u'F': 3}, {u'T': 6, u'F': 3}, {u'T': 7, u'F': 3}, {u'T': 8, u'F': 3}, {u'T': 9, u'F': 3}, {u'T': 10, u'F': 3}, {u'T': 11, u'F': 3}, {u'T': 0, u'F': 4}, {u'T': 1, u'F': 4}, {u'T': 2, u'F': 4}, {u'T': 3, u'F': 4}, {u'T': 4, u'F': 4}, {u'T': 5, u'F': 4}, {u'T': 6, u'F': 4}, {u'T': 7, u'F': 4}, {u'T': 8, u'F': 4}, {u'T': 9, u'F': 4}, {u'T': 10, u'F': 4}, {u'T': 11, u'F': 4}, {u'T': 0, u'F': 5}, {u'T': 1, u'F': 5}, {u'T': 2, u'F': 5}, {u'T': 3, u'F': 5}, {u'T': 4, u'F': 5}, {u'T': 5, u'F': 5}, {u'T': 6, u'F': 5}, {u'T': 7, u'F': 5}, {u'T': 8, u'F': 5}, {u'T': 9, u'F': 5}, {u'T': 10, u'F': 5}, {u'T': 11, u'F': 5}, {u'T': 0, u'F': 6}, {u'T': 1, u'F': 6}, {u'T': 2, u'F': 6}, {u'T': 3, u'F': 6}, {u'T': 4, u'F': 6}, {u'T': 5, u'F': 6}, {u'T': 6, u'F': 6}, {u'T': 7, u'F': 6}, {u'T': 8, u'F': 6}, {u'T': 9, u'F': 6}, {u'T': 10, u'F': 6}, {u'T': 11, u'F': 6}, {u'T': 0, u'F': 7}, {u'T': 1, u'F': 7}, {u'T': 2, u'F': 7}, {u'T': 3, u'F': 7}, {u'T': 4, u'F': 7}, {u'T': 5, u'F': 7}, {u'T': 6, u'F': 7}, {u'T': 7, u'F': 7}, {u'T': 8, u'F': 7}, {u'T': 9, u'F': 7}, {u'T': 10, u'F': 7}, {u'T': 11, u'F': 7}, {u'T': 0, u'F': 8}, {u'T': 1, u'F': 8}, {u'T': 2, u'F': 8}, {u'T': 3, u'F': 8}, {u'T': 4, u'F': 8}, {u'T': 5, u'F': 8}, {u'T': 6, u'F': 8}, {u'T': 7, u'F': 8}, {u'T': 8, u'F': 8}, {u'T': 9, u'F': 8}, {u'T': 10, u'F': 8}, {u'T': 11, u'F': 8}, {u'T': 0, u'F': 9}, {u'T': 1, u'F': 9}, {u'T': 2, u'F': 9}, {u'T': 3, u'F': 9}, {u'T': 4, u'F': 9}, {u'T': 5, u'F': 9}, {u'T': 6, u'F': 9}, {u'T': 7, u'F': 9}, {u'T': 8, u'F': 9}, {u'T': 9, u'F': 9}, {u'T': 10, u'F': 9}, {u'T': 11, u'F': 9}, {u'T': 0, u'F': 10}, {u'T': 1, u'F': 10}, {u'T': 2, u'F': 10}, {u'T': 3, u'F': 10}, {u'T': 4, u'F': 10}, {u'T': 5, u'F': 10}, {u'T': 6, u'F': 10}, {u'T': 7, u'F': 10}, {u'T': 8, u'F': 10}, {u'T': 9, u'F': 10}, {u'T': 10, u'F': 10}, {u'T': 11, u'F': 10}, {u'T': 0, u'F': 11}, {u'T': 1, u'F': 11}, {u'T': 2, u'F': 11}, {u'T': 3, u'F': 11}, {u'T': 4, u'F': 11}, {u'T': 5, u'F': 11}, {u'T': 6, u'F': 11}, {u'T': 7, u'F': 11}, {u'T': 8, u'F': 11}, {u'T': 9, u'F': 11}, {u'T': 10, u'F': 11}, {u'T': 11, u'F': 11}]
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 45.5555555556 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 45.5555555556 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 42.2222222222 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 20.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 5.55555555556 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 2.22222222222 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 0.0 compared with 0
# threshold from the last round: 0
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 45.5555555556 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 45.5555555556 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 42.2222222222 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 20.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 5.55555555556 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 2.22222222222 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 0.0 compared with 1
# threshold from the last round: 1
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 45.5555555556 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 45.5555555556 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 42.2222222222 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 20.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 5.55555555556 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 2.22222222222 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 0.0 compared with 2
# threshold from the last round: 2
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 45.5555555556 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 45.5555555556 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 42.2222222222 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 20.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 5.55555555556 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 2.22222222222 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 0.0 compared with 3
# threshold from the last round: 3
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 45.5555555556 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 45.5555555556 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 42.2222222222 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 20.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 5.55555555556 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 2.22222222222 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 0.0 compared with 4
# threshold from the last round: 4
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 45.5555555556 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 45.5555555556 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 42.2222222222 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 20.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 5.55555555556 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 2.22222222222 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 0.0 compared with 5
# threshold from the last round: 5
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 50.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 45.5555555556 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 45.5555555556 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 42.2222222222 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 20.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 5.55555555556 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 2.22222222222 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 0.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 0.0 compared with 6
# threshold from the last round: 6
#
# get_validation: Acc_Macro - 50.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 50.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 50.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 50.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 45.5555555556 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 45.5555555556 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 42.2222222222 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 20.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 5.55555555556 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 2.22222222222 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 0.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 0.0 compared with 7
# threshold from the last round: 7
#
# get_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 50.0 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 45.5555555556 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 45.5555555556 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 42.2222222222 compared with 8
# threshold from the last round: 8
#
# get_validation: Acc_Macro - 20.0 compared with 8
# threshold from the last round: 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-f8a41e218beb> in <module>()
#       2     data_name, k_holdout, k_cv, pars = run_Config()
#       3     all_fea, all_label = run_load_data(data_name)
# ----> 4     res_list, opt_pars_list = run_doubleCV(all_fea, all_label, k_holdout, k_cv, pars)
#       5     print 'Each heldout cv result:'
#       6     print '-----------------------'
#
# <ipython-input-10-6728833f3482> in run_doubleCV(all_fea, all_label, k_holdout, k_cv, pars)
#      37                 # learn the model
#      38                 # i_pars = {'par_name1':par1,'par_name2':par2,...,'par_nameN':parN}
# ---> 39                 valid_pre, pars_new = run_RuleDiscovery(i_pars, train_fea, train_label, valid_fea)
#      40                 eval_dict = run_evaluation(valid_pre, valid_label)
#      41                 grid_score = eval_dict[i_pars['indicator_name']]
#
# <ipython-input-12-2a967e1191cb> in run_RuleDiscovery(p, X, y, Z)
#       6     # threshold = [(t,c),(t,c),...,(t,c)]
#       7     rule = get_rules(X, y, p)
# ----> 8     threshold = get_validation(X, y, rule, p)
#       9     p['threshold'] = threshold
#      10
#
# <ipython-input-14-0c7b6d81826b> in get_validation(data, label, rule, par)
#      18         for c in class_name: # each class makes a prediction for the data
#      19             threshold_now = i_t[c]
# ---> 20             pre_rule_num = get_micro_predict(data, class_rule[c])
#      21             pre_now[c] = [c if i_r > threshold_now else None for i_r in pre_rule_num]
#      22         pre_label = get_voted_pre(pre_now)
#
# <ipython-input-14-0c7b6d81826b> in get_micro_predict(data, rule)
#      36     for i_data in xrange(len(data.index)):
#      37         sample = zip(data.iloc[i_data,:], data.columns)
# ---> 38         match_num = get_match(sample, rule)
#      39         pre_rule_num.extend([match_num])
#      40     return pre_rule_num
#
# <ipython-input-14-0c7b6d81826b> in get_match(sample, rule)
#      43     match_num = 0
#      44     for i_v, i_f in sample:
# ---> 45         for j_v, j_f, _ in rule:
#      46             if i_f == j_f and i_v == j_v:
#      47                 match_num = match_num + 1
#
# KeyboardInterrupt:
